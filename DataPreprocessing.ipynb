# %%
import sys,os
sys.path.append(os.pardir)
import matplotlib.pyplot as plt
import numpy as np
import cv2

# img_num1 = len(os.listdir("/home/gus/cattrain"))
# img_num2 = len(os.listdir("/home/gus/cattest"))
# ====================================
# """Choosing uniform size"""
# x_train = []
# x_train_shape = []
# for i in range(4000):
#     img = cv2.imread('/home/gus/cattrain/cat.{0}.jpg'.format(i),cv2.IMREAD_COLOR)
#     x_train.append(img)
#     x_train_shape.append(np.asarray(img.shape))
# for i in range(4000):
#     img = cv2.imread('/home/gus/cattrain/dog.{0}.jpg'.format(i),cv2.IMREAD_COLOR)
#     x_train.append(img)
#     x_train_shape.append(np.asarray(img.shape))

# x_train_shape = np.array(x_train_shape)
# x_train_mean = np.mean(x_train_shape,axis = 0)

# array([360.49875, 403.84675,   3.     ])  -> choose H360,W404
# =====================================
# """making x_train(n=8000)"""

# x_train = []
# for i in range(4000):
#     img = cv2.imread('/home/gus/cattrain/cat.{0}.jpg'.format(i),cv2.IMREAD_COLOR)
#     img = cv2.resize(img,dsize=(404,360),interpolation=cv2.INTER_LINEAR)
#     x_train.append(img)
# for i in range(4000):
#     img = cv2.imread('/home/gus/cattrain/dog.{0}.jpg'.format(i),cv2.IMREAD_COLOR)
#     img = cv2.resize(img,dsize=(404,360),interpolation=cv2.INTER_LINEAR)
#     x_train.append(img)

# x_train = np.array(x_train)
# np.save('x_train.npy', x_train)
# ======================================
# """making x_test(n=4000)"""

# x_test = []
# for i in range(4000):
#     img = cv2.imread('/home/gus/cattest/{0}.jpg'.format(i+1), cv2.IMREAD_COLOR)
#     img = cv2.resize(img ,dsize=(404,360), interpolation=cv2.INTER_LINEAR)
#     x_test.append(img)

# x_test = np.array(x_test)
# np.save('x_test.npy',x_test)
# =====================================
# """making x_test(n=2000)"""

# x_test = []
# for i in range(5000,6000,1):
#     img = cv2.imread('/home/gus/cattrain/cat.{0}.jpg'.format(i),cv2.IMREAD_COLOR)
#     img = cv2.resize(img,dsize=(404,360),interpolation=cv2.INTER_LINEAR)
#     x_test.append(img)
# for i in range(5000,6000,1):
#     img = cv2.imread('/home/gus/cattrain/dog.{0}.jpg'.format(i),cv2.IMREAD_COLOR)
#     img = cv2.resize(img,dsize=(404,360),interpolation=cv2.INTER_LINEAR)
#     x_test.append(img)

# x_test = np.array(x_test)
# np.save('x_test.npy', x_test)
# ======================================
# """making t_test(n=1000)"""

# t_test = []
# for i in range(5000,6000,1):
#     img = cv2.imread('/home/gus/cattest/{0}.jpg'.format(i+1), cv2.IMREAD_COLOR)
#     img = cv2.resize(img ,dsize=(404,360), interpolation=cv2.INTER_LINEAR)
#     t_test.append(img)

# t_test = np.array(t_test)
# np.save('t_test.npy',t_test)
# ======================================

# x_train = np.load('/home/gus/deep-learning-from-scratch-master/ch08/x_train.npy')
# t_train = np.load('/home/gus/deep-learning-from-scratch-master/ch08/t_train.npy')
# x_test = np.load('/home/gus/deep-learning-from-scratch-master/ch08/x_test.npy')
# t_test = np.load('/home/gus/deep-learning-from-scratch-master/ch08/t_test.npy')

# %%
img = cv2.imread('/home/gus/cattrain/cat.10.jpg',cv2.IMREAD_COLOR)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
print(img.shape)
plt.subplot(121)
plt.imshow(img)
img = cv2.resize(img,dsize=(404,360),interpolation=cv2.INTER_LINEAR)
print(img.shape)
# img = img.transpose(2,0,1)
print(img.shape)
plt.subplot(122)
plt.imshow(img)
# Out:
# (499, 489, 3)
# (360, 404, 3)
# (360, 404, 3)
